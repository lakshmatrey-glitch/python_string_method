# %% [markdown]
# # String Methods

# %%
string = ("HELLO WORLD")

# %%
string.lower()
# Out:
# 'hello world'

# %%
string = ("hello world")

# %%
string.upper()
# Out:
# 'HELLO WORLD'

# %%
string = ("hello sun")

# %%
string.title()
# Out:
# 'Hello Sun'

# %%
string = ("hello mars")

# %%
string.capitalize()
# Out:
# 'Hello mars'

# %%
string = ("hello jupiter")

# %%
string.swapcase()
# Out:
# 'HELLO JUPITER'

# %%
string = ("HELLO pluto")

# %%
string.casefold()
# Out:
# 'hello pluto'

# %%
string = ("doing my assigment today")

# %%
string.find(" ")
# Out:
# 5

# %%
string.find("a")
# Out:
# 9

# %%
string = ("going to complete it today")
string.rfind("it")
# Out:
# 18

# %%
string = "some of the methods i am unable to understand"

# %%
string.index("understand")
# Out:
# 35

# %%
string = "hello world"

# %%
string.rindex("world")
# Out:
# 6

# %%
string = "hello world"

# %%
string.count("hello")
# Out:
# 1

# %%
string = "hello world"

# %%
string.startswith("my")
# Out:
# False

# %%
string.startswith("hello")
# Out:
# True

# %%
string = "hello world"

# %%
string.endswith("my")
# Out:
# False

# %%
string.endswith("world")
# Out:
# True

# %%
string = "hello world"

# %%
string.isalnum()
# Out:
# False

# %%
string = "helloworld123"

# %%
string.isalnum()
# Out:
# True

# %%
string = "hello world"

# %%
string.isalpha()
# Out:
# False

# %%
string = "HELLO"

# %%
string.isalpha()
# Out:
# True

# %%
string = "12345"

# %%
string.isdigit()
# Out:
# True

# %%
string = "hello world"

# %%
string.isdigit()
# Out:
# False

# %%
string = "1234a"

# %%
string.isdecimal()
# Out:
# False

# %%
string = "12345"

# %%
string.isdecimal()
# Out:
# True

# %%
string = "1234"

# %%
string.isnumeric()
# Out:
# True

# %%
string = "123desaww"

# %%
string.isnumeric()
# Out:
# False

# %%
string = "Hello world"
string.islower()
# Out:
# False

# %%
string = "hello"
string.islower()
# Out:
# True

# %%
string = "hello123!"
string.islower()
# Out:
# True

# %%
string = "1234!"
string.islower()
# Out:
# False

# %%
string = "hello world"
string.isupper()
# Out:
# False

# %%
string = "HELLO WORLD"
string.isupper()
# Out:
# True

# %%
string = "    "
string.isspace()
# Out:
# True

# %%
string = "HELLO"
string.isspace()
# Out:
# False

# %%
string = "hello world"
string.istitle()
# Out:
# False

# %%
string = "Hello World"

# %%
string.istitle()
# Out:
# True

# %%
string = "hello world"

# %%
string.isidentifier()
# Out:
# False

# %%
string = "hello1234"
string.isidentifier()
# Out:
# True

# %%
string = "hello_"

# %%
string.isidentifier()
# Out:
# True

# %%
string = "hello world"

# %%
string.isprintable()
# Out:
# True

# %%
string = "Line1\nLine2"

# %%
string.isprintable()
# Out:
# False

# %%
string = "hello world"
string.split()
# Out:
# ['hello', 'world']

# %%
string = "sunday monday tuesday wednesday thursday friday saturday sundar"
string.split()
# Out:
# ['sunday',
#  'monday',
#  'tuesday',
#  'wednesday',
#  'thursday',
#  'friday',
#  'saturday',
#  'sundar']

# %%
string = "sunday monday tuesday"
string.rstrip()
# Out:
# 'sunday monday tuesday'

# %%
string = "hello world i am new in python"
string.splitlines()
# Out:
# ['hello world i am new in python']

# %%
string = "hello world"
string.join("hello")
# Out:
# 'hhello worldehello worldlhello worldlhello worldo'

# %%
string = "hello world"
string.replace("hello","My")
# Out:
# 'My world'

# %%
string = "hello world"
string.strip()
# Out:
# 'hello world'

# %%
string = "hello world"
string.rstrip()
# Out:
# 'hello world'

# %%
string = "hello world"
string.removeprefix("hello")
# Out:
# ' world'

# %%
string = "hello world"
string.removesuffix("world")
# Out:
# 'hello '

# %%
string = "hello world"
string.expandtabs()
# Out:
# 'hello world'

# %%
string = "Hello"
string.center("11")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 2
#       1 string = "Hello"
# ----> 2 string.center("11")
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
string = "123"
string.ljust("1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[179], line 2
#       1 string = "123"
# ----> 2 string.ljust("1")
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
string = "hello world"
string.rjust("26")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 2
#       1 string = "hello world"
# ----> 2 string.rjust("26")
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
string = "hello world"
string.zfill(10)
# Out:
# 'hello world'

# %%
string = "hello world"
string.format()
# Out:
# 'hello world'

# %%
string = "hello world"
string.format_map("world")
# Out:
# 'hello world'
